# %% [markdown]
# entropy : 정보를 표현하는데 필요한 최소 자원량 -> (0 or 1의 길이, bits의 단위)

# %% [markdown]
# 어떤 정보를 표현하게 될지 모르지만 정보를 표현 할 때 최소한의 자원을 사용하는게 효율적인데 자주 사용하는 정보는 bits를 짧게, 사용 빈도가 낮은 정보는 bits를 길게 만들어서 이용

# %%
from IPython.display import Image 
Image("img/Cross_Entropy.jpg")
